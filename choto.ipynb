# %%
using Distributions, Plots

supp=[17, 50, 83.0]
p=1/length(supp)*ones(size(supp))*1.0
d=DiscreteNonParametric(supp,p)

x=(0:0.1:100)

plot(x,cdf.(d,x))
plot!(x,x/100)
# Out:
# Plot{Plots.GRBackend() n=2}
